# %% [markdown]
# ### imports

# %%
from mtcnn import MTCNN
import cv2
import os
from glob import glob

# %% [markdown]
# ## Multifile approach

# %%
folder_list = glob(os.path.join("../../raw_data/Test_cast/", '*'))
#print(filename_list)

filename_list = []
for folder in folder_list:
    filename_list.append(glob(os.path.join(folder, "*.jpg")))

# %%
filename_list
# Out:
# [['../../raw_data/Test_cast/Pam/Pam_021.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_010.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_013.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_016.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_029.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_028.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_027.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_012.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_030.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_006.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_019.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_015.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_024.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_008.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_014.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_002.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_007.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_005.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_026.jpg',
#   '../../raw_data/Test_cast/Pam/Pam_023.jpg',
# ...

# %%
detector = MTCNN()

for img_path in filename_list:
    for i, img in enumerate(img_path):
        try:
            image = cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB)
            #Outputs a faces list of dict, with the bounding box inside the key 'box'
            faces = detector.detect_faces(image)
            crop_faces(img, image, faces)
        except:
            continue
# Out:
# ...
# 1/1 [==============================] - 0s 226ms/step
# ../../raw_data/cropped_new/Pam/Pam_021_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 48ms/step
# ../../raw_data/cropped_new/Pam/Pam_010_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 51ms/step
# ../../raw_data/cropped_new/Pam/Pam_013_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 48ms/step
# ../../raw_data/cropped_new/Pam/Pam_016_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 49ms/step
# ../../raw_data/cropped_new/Pam/Pam_029_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 57ms/step
# ../../raw_data/cropped_new/Pam/Pam_028_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 45ms/step
# ../../raw_data/cropped_new/Pam/Pam_027_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 61ms/step
# ../../raw_data/cropped_new/Pam/Pam_012_face0.jpg is saved
# ...
# 1/1 [==============================] - 0s 40ms/step
# ...

# %%
'''
Iterates through a dictionary of faces from MTCNN detection, crops and saves them in a new folder
'''
def crop_faces(img, image, faces):
    if len(faces) > 0:
        for i, face in enumerate(faces):
            x, y, w, h = face['box']
            
            # get face and save crop
            face = image[y:y + h, x:x + w]
            face = cv2.cvtColor(face, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f"{img[:-4].replace('Test_cast', 'cropped_new')}_face{i}.jpg", face)
            print(f"{img[:-4].replace('Test_cast', 'cropped_new')}_face{i}.jpg is saved")
    return None

# %%
img[:-4].replace('Kaggle_clean', 'cropped')
# Out:
# '../../raw_data/cropped/Pam/extra_15'

# %%
img
# Out:
# '../../raw_data/Test_cast/Dwight/Dwight_027.jpg'

# %% [markdown]
# ## Test dataset

# %%
folder_list = glob(os.path.join("../../raw_data/cast/", '*'))
#print(filename_list)

filename_list = []
for folder in folder_list:
    filename_list.append(glob(os.path.join(folder, "*.jpg")))

# %%
'''
Iterates through a dictionary of faces from MTCNN detection, crops and saves them in a new folder
'''
def crop_faces(img, image, faces):
    if len(faces) > 0:
        for i, face in enumerate(faces):
            x, y, w, h = face['box']
            
            # get face and save crop
            face = image[y:y + h, x:x + w]
            face = cv2.cvtColor(face, cv2.COLOR_RGB2BGR)
            cv2.imwrite(f"{img[:-4]}_face{i}.png", face)
            print(f"{img[:-4]}_face{i}.png is saved")
    return None

# %%
detector = MTCNN()

for img_path in filename_list:
    for i, img in enumerate(img_path):
        image = cv2.cvtColor(cv2.imread(img), cv2.COLOR_BGR2RGB)
        #Outputs a faces list of dict, with the bounding box inside the key 'box'
        faces = detector.detect_faces(image)
        crop_faces(img, image, faces)
# Out:
# ...
# 1/1 [==============================] - 0s 444ms/step
# ../../raw_data/cast/Pam/jf5_face0.png is saved
# ...
# 1/1 [==============================] - 0s 51ms/step
# ../../raw_data/cast/Pam/jf2_face0.png is saved
# ...
# 1/1 [==============================] - 0s 64ms/step
# ../../raw_data/cast/Pam/jf3_face0.png is saved
# ...
# 1/1 [==============================] - 0s 58ms/step
# ../../raw_data/cast/Pam/jf1_face0.png is saved
# ...
# 1/1 [==============================] - 0s 47ms/step
# ../../raw_data/cast/Pam/jf4_face0.png is saved
# ...
# 1/1 [==============================] - 0s 48ms/step
# ../../raw_data/cast/Dwight/RW1jpg_face0.png is saved
# ...
# 1/1 [==============================] - 0s 43ms/step
# ../../raw_data/cast/Dwight/RainnWilson2_face0.png is saved
# ...
# 1/1 [==============================] - 0s 64ms/step
# ../../raw_data/cast/Dwight/Dwight-the-office_face0.png is saved
# ../../raw_data/cast/Dwight/Dwight-the-office_face1.png is saved
# ...
# 1/1 [==============================] - 0s 48ms/step
# ...

# %% [markdown]
# # Single file approach

# %%
img_path = 'img/'
img_file = 'lateral.jpg'
img_type = img_file.split('.')[1]
image = cv2.cvtColor(cv2.imread(f'{img_path}{img_file}'), cv2.COLOR_BGR2RGB)
#Outputs a faces list of dict, with the bounding box inside the key 'box'
detector = MTCNN()
faces = detector.detect_faces(image)
# Out:
# 2023-03-22 09:26:57.642107: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-03-22 09:26:57.642749: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/daniel/.pyenv/versions/3.10.6/envs/computer_vision/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-03-22 09:26:57.642973: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/daniel/.pyenv/versions/3.10.6/envs/computer_vision/lib/python3.10/site-packages/cv2/../../lib64:
# ...

# %%
if len(faces) > 0:
    for i, face in enumerate(faces):
        x, y, w, h = face['box']
        
        # get face and save crop
        face = image[y:y + h, x:x + w] 
        cv2.imwrite(f'{img_path}face{i}.{img_type}', face)
        print(f"face{i}.{img_type} is saved")    
        cv2.imshow("Cropped Face", face)
        
        # draw rectangle
        color = (0, 255, 255) # in BGR
        stroke = 1
        cv2.rectangle(image, (x, y), (x + w, y + h), color, stroke)

# Show both images, press any key to exit     
cv2.imshow('Face detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# face0.jpg is saved
# face1.jpg is saved
# face2.jpg is saved

# %% [markdown]
# ## Final version saving faces in RGB

# %%
if len(faces) > 0:
    for i, face in enumerate(faces):
        x, y, w, h = face['box']
        
        # get face and save crop
        face = image[y:y + h, x:x + w]
        face = cv2.cvtColor(face, cv2.COLOR_RGB2BGR)
        cv2.imwrite(f'{img_path}face{i}.{img_type}', face)
        print(f"face{i}.{img_type} is saved")    
        #cv2.imshow("Cropped Face", face)
        
        # draw rectangle
        color = (0, 255, 255) # in BGR
        stroke = 1
        cv2.rectangle(image, (x, y), (x + w, y + h), color, stroke)

# Show both images, press any key to exit     
cv2.imshow('Face detection', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# face0.jpg is saved
# face1.jpg is saved
# face2.jpg is saved
