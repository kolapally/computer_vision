# %% [markdown]
# We need to install dlib

# %%
import dlib

# %%
import matplotlib.pyplot as plt
import numpy as np
import mtcnn

# %%
detector = mtcnn.MTCNN()
sp = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

# %%
import os
from glob import glob

filename_list = glob(os.path.join("../data/Cast/Ellie Kemper/", "*.jpg"))

# %%
detector = dlib.cnn_face_detection_model_v1('../mmod_human_face_detector.dat')

# %%
# detector = dlib.cnn_face_detection_model_v1('../mmod_human_face_detector.dat')
sp = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')
img_path = '../dlib_preprocess/Capture.JPG'
img = dlib.load_rgb_image(img_path)
img_detected = detector(img,1)

img_shape = []
for i in range(len(img_detected)):
    img_detected[i][]
    img_shape.append(sp(img,img_detected[i]))
# img_alligned=[]
# for i in range(len(img_shape)):
#     img_alligned.append(dlib.get_face_chip(img,img_shape[i]))

# %%
img_detected[0].re

# %%
len(img_alligned)
# Out:
# 2

# %%
plt.imshow(img_alligned[1])

# %%
img_detected
# Out:
# rectangles[[(233, 153) (285, 205)], [(-9, 211) (49, 262)]]

# %%
images = []
for file in filename_list:
    images.append(dlib.load_rgb_image(file))

# %%
img_detected = []
for img in images:
    img_detected.append(detector(img,1))

# %%
len(img_detected)

# %%
img_detected

# %%
img_shape = []
for i in range(len(images)):
    img_shape.append(sp(images[i],img_detected[i][0]))
# img2_shape = sp(img2,img2_detected[0])

# %%
img_alligned = []
for i in range(len(images)):
    img_alligned.append(dlib.get_face_chip(images[i],img_shape[i]))
# img2_alligned = dlib.get_face_chip(img2,img2_shape)

# %%
plt.imshow(img_alligned[0])
plt.show()
# plt.imshow(img2_alligned)
# plt.show()

# %%
np.array(img_alligned).shape
# Out:
# (5, 150, 150, 3)

# %%
from PIL import Image

for i in range(np.array(img_alligned).shape[0]):
    im = Image.fromarray(np.array(img_alligned)[i, :, :, :])
    im.save(f"../data/Cast/Ellie Kemper/Ellie_kemper{i}.jpg", 'JPEG')
